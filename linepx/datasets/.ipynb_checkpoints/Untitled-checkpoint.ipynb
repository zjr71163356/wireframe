# %%
     import torch
     print(torch.cuda.is_available())  # Should return True
     print(torch.cuda.current_device())  # Should return the GPU index
# Out:
# True
# 0

# %%
 
         print("Line data contains NaN or Inf values")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_32426/1697991808.py in <module>
# ----> 1 if torch.isnan(inputData_var).any() or torch.isinf(inputData_var).any():
#       2     print("Input data contains NaN or Inf values")
#       3 if torch.isnan(line_var).any() or torch.isinf(line_var).any():
#       4     print("Line data contains NaN or Inf values")
#       5
#
# NameError: name 'inputData_var' is not defined
